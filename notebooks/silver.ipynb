# %%
import sys
from pathlib import Path
sys.path.insert(0,str(Path().resolve().parent))

# %%
from src.utils.db import connect_to_db

#instanciating an engine
engine= connect_to_db()
# Out:
# parameters of DATABASE sucessfuly loaded
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from src.utils.db import connect_to_db
#       2
#       3 #instanciating an engine
# ----> 4 engine= connect_to_db()
#
# File ~/technofutur/15-final_project/belgian-environement-monitor/src/utils/db.py:31, in connect_to_db()
#      28 print("parameters of DATABASE sucessfuly loaded ")
#      30 #instanciation of the engine
# ---> 31 engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}')
#      33 #test of connection
#      34 with engine.connect() as conn:
#
# NameError: name 'PASSWORD' is not defined
